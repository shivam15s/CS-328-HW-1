# %%
import plotly_express as px
import numpy as np
import pandas as pd

# %%
gdp = pd.read_csv("gdppercapita_us_inflation_adjusted.csv")

# %%
gdp
# Out:
#          country     1960     1961     1962     1963     1964     1965  \
# 0    Afghanistan      NaN      NaN      NaN      NaN      NaN      NaN
# 1        Albania      NaN      NaN      NaN      NaN      NaN      NaN
# 2        Algeria   2480.0   2090.0   1640.0   2150.0   2210.0   2290.0
# 3        Andorra      NaN      NaN      NaN      NaN      NaN      NaN
# 4         Angola      NaN      NaN      NaN      NaN      NaN      NaN
# ..           ...      ...      ...      ...      ...      ...      ...
# 186    Venezuela  12500.0  12400.0  13000.0  13000.0  14000.0  14100.0
# 187      Vietnam      NaN      NaN      NaN      NaN      NaN      NaN
# 188        Yemen      NaN      NaN      NaN      NaN      NaN      NaN
# 189       Zambia   1500.0   1470.0   1390.0   1400.0   1520.0   1720.0
# 190     Zimbabwe    995.0   1020.0   1000.0   1030.0    985.0    999.0
#
#         1966     1967     1968  ...   2010     2011     2012     2013  \
# ...

# %%
gdp_f = gdp.melt('country')
gdp_f.columns = ['country', 'year', 'gdpPercap']

# %%
gdp_f.isnull().sum()
# Out:
# country         0
# year            0
# gdpPercap    2461
# dtype: int64

# %%
internet = pd.read_csv("internet_users.csv")

# %%
internet
# Out:
#          country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 0    Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1        Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2        Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3        Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4         Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 189    Venezuela   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 190      Vietnam   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 191        Yemen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 192       Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 193     Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...

# %%
internet_f = internet.melt('country')
internet_f.columns = ['country', 'year', 'internetUsers']

# %%
internet_f
# Out:
#            country  year  internetUsers
# 0      Afghanistan  1960            NaN
# 1          Albania  1960            NaN
# 2          Algeria  1960            NaN
# 3          Andorra  1960            NaN
# 4           Angola  1960            NaN
# ...            ...   ...            ...
# 11635    Venezuela  2019            NaN
# 11636      Vietnam  2019           68.7
# 11637        Yemen  2019            NaN
# 11638       Zambia  2019            NaN
# 11639     Zimbabwe  2019            NaN
#
# [11640 rows x 3 columns]

# %%
df = pd.merge(gdp_f, internet_f, how='inner', on=['country', 'year'])

# %%
df
# Out:
#            country  year  gdpPercap  internetUsers
# 0      Afghanistan  1960        NaN            NaN
# 1          Albania  1960        NaN            NaN
# 2          Algeria  1960     2480.0            NaN
# 3          Andorra  1960        NaN            NaN
# 4           Angola  1960        NaN            NaN
# ...            ...   ...        ...            ...
# 11455    Venezuela  2019        NaN            NaN
# 11456      Vietnam  2019     2080.0           68.7
# 11457        Yemen  2019        NaN            NaN
# 11458       Zambia  2019     1660.0            NaN
# 11459     Zimbabwe  2019     1180.0            NaN
#
# [11460 rows x 4 columns]

# %%
pop = pd.read_csv('population_total.csv')

# %%
pop_f = pop.melt('country')
pop_f.columns = ['country', 'year', 'population']

# %%
pop_f
# Out:
#            country  year  population
# 0      Afghanistan  1800     3280000
# 1          Albania  1800      400000
# 2          Algeria  1800     2500000
# 3          Andorra  1800        2650
# 4           Angola  1800     1570000
# ...            ...   ...         ...
# 58690    Venezuela  2100    34200000
# 58691      Vietnam  2100    97400000
# 58692        Yemen  2100    53200000
# 58693       Zambia  2100    81500000
# 58694     Zimbabwe  2100    31000000
#
# [58695 rows x 3 columns]

# %%
df = pd.merge(df, pop_f, how='inner', on=['country', 'year'])

# %%
df['internetUsers'] = df['internetUsers'].astype(float)

# %%
ctr_dic = {}
for country,data in df.groupby(["country"]):
    ctr_dic[country] = data

# %%
for country, df_ctr in ctr_dic.items():
    df_ctr.fillna(method='ffill', inplace=True)
    df_ctr['internetUsers'].fillna(0, inplace=True)
    df_ctr.fillna(method='bfill', inplace=True)

# %%
for key in ctr_dic.keys():
    try:
        df_formatted = pd.concat([df_formatted, ctr_dic[key]])
    except:
        df_formatted = ctr_dic[key]

# %%
df_formatted.year = df_formatted.year.astype(int)

# %%
df_formatted = df_formatted[df_formatted.year>1990]

# %% [markdown]
# ## Internet Users vs GDP (Per Capita)

# %%
df_formatted
# Out:
#            country  year  gdpPercap  internetUsers  population
# 5921   Afghanistan  1991      330.0            0.0    13300000
# 6112   Afghanistan  1992      330.0            0.0    14500000
# 6303   Afghanistan  1993      330.0            0.0    15800000
# 6494   Afghanistan  1994      330.0            0.0    17100000
# 6685   Afghanistan  1995      330.0            0.0    18100000
# ...            ...   ...        ...            ...         ...
# 10695     Zimbabwe  2015     1230.0           22.7    13800000
# 10886     Zimbabwe  2016     1220.0           23.1    14000000
# 11077     Zimbabwe  2017     1260.0           27.1    14200000
# 11268     Zimbabwe  2018     1310.0           27.1    14400000
# 11459     Zimbabwe  2019     1180.0           27.1    14600000
#
# [5539 rows x 5 columns]

# %%
fig = px.scatter(df_formatted, x='gdpPercap', y='internetUsers', animation_frame='year', animation_group='country', size='population', color='country', hover_name='country', size_max=70, log_x=True, range_x=[100, 100000], range_y=[-10, 110], title='Internet Users vs GDP (Per Capita)')

# %%
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 1200
fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 1200

# %%
fig.write_html('internet_users_vs_gdp')
